# %%
import pandas as pd
import numpy as np
from enum import Enum
from IPython.display import display, HTML

# Constants - Market Data
DATE = 'date'
OPEN = 'open'
HIGH = 'high'
LOW = 'low'
CLOSE = 'close'
ADJ_CLOSE = 'adj_close'
VOLUME = 'volume'

# Constants - Position
BULLISH = 'bullish'
BEARISH = 'bearish'

# Constants - Strategy Events
OPEN_POSITION = 'open_position'
CLOSE_POSITION = 'close_position'
NO_EVENT = 'no_event'

# Technical Indicator
TI_CCI = 'CCI'


def display_df(df):
    display(HTML(df.to_html()))

# %%
class DataCleaner():
    
    def __init__(self):
        self.dropna_method = 'all'
        self.is_fill_missing = True
    
    def clean(self, raw_data):
        raw_data = raw_data.dropna(how=self.dropna_method)
        if self.is_fill_missing:
            raw_data = self.fill_missing_date(raw_data)
        return raw_data
    
    @staticmethod
    def fill_missing_date(raw_data):
        cols = list(raw_data.columns)
        cols.remove(DATE)
        for col in cols:
            for i in raw_data.index:
                element = raw_data.at[i, col]
                if np.isnan(element) or element == 0:
                    missing_data_date = raw_data.at[i, DATE]
                    ref_data_date = raw_data.at[i-1, 'date']
                    raw_data.at[i, col] = raw_data.at[i-1, col]
                    print('[CLEAN] Copy data ({}, {}) to ({}, {}))'
                          .format(ref_data_date, col, missing_data_date, col))
        return raw_data

# %%
class TechIndicatorEngine():
    def __init__(self):
        pass
    
    def compute(self, data, ti_param):
        if self.extract_alphabet(ti_param.name) == TI_CCI:
            cci = CCI(ti_param)
            data = cci.compute(data)
        else:
            raise ValueError('[ERROR] Unknown technical indicator: {}'.format(ti_param.name))
        
        print('[TechIndicatorEngine] Finished computation of {}'.format(ti_param.name))
        return data
    
    @staticmethod
    def extract_alphabet(s):
        return ''.join(x for x in s if x.isalpha())

# %%
class IndicatorParam():
    def __init__(self, name):
        self.name = name
        
    def __eq__(self, other):
        if self.__class__ != other.__class__:
            return False
        return self.__dict__ == other.__dict__


class CCIParam(IndicatorParam):
    def __init__(self, period, coeff):
        super().__init__(TI_CCI)
        self.period = period
        self.coeff = coeff


class CCI():
    
    def __init__(self, param):
        self.param = param
        
    def compute(self, data):
        
        # typical price
        data['typical'] = data[[HIGH, LOW, CLOSE]].apply(lambda row: self.typical_price(row), axis=1)
        
        # moving average of typical price
        data['MA'] = data['typical'].rolling(window=self.param.period).mean()
        
        # absolute difference between typical price and MA
        data['abs_diff'] = data[['typical', 'MA']].apply(lambda row: abs(row['typical'] - row['MA']), axis=1)
        
        # mean deviation
        data['MD'] = data['abs_diff'].rolling(window=self.param.period).mean()
        
        # CCI
        data[self.param.name] = data[['typical', 'MA', 'MD']].apply(lambda row: self.cci_formula(row), axis=1)
        
        # drop columns for intermediate steps
        data = data.drop(columns=['typical', 'MA', 'abs_diff', 'MD'])
        
        return data
        
    @staticmethod
    def typical_price(row):
        return (row[HIGH] + row[LOW] + row[CLOSE]) / 3
    
    def cci_formula(self, row):
        return (row['typical'] - row['MA']) / (self.param.coeff * row['MD'])

# %%
class Rule():
    def __init__(self, name, indicators_param, ref, f):
        self.name = name
        self.indicators_param = indicators_param
        self.ref = ref
        self.f = f

class OpenPositionParam():
    def __init__(self, rules):
        self.rules = rules  # rule: f(data, ref, self.entry_index, current_index) -> boolean

class ClosePositionParam():
    def __init__(self, rules):
        self.rules = rules  # rule : f(data, ref, self.entry_index, current_index) -> boolean


class Strategy():

    def __init__(self, name, open_position_param, close_position_param, position):
        self.name = name
        self.open_position = open_position_param
        self.close_position = close_position_param
        self.position = position
        self.have_position = False
        self.entry_index = None
        
    def check_event(self, data, current_index):       
        if not self.have_position:  # check for open position
            rule_triggered = self.check_rules(data, current_index, self.open_position.rules)
            if rule_triggered:
                self.have_position = True
                self.entry_index = current_index
                return OPEN_POSITION, rule_triggered
            
        else:  # check for close positioin
            rule_triggered = self.check_rules(data, current_index, self.close_position.rules)
            if rule_triggered:
                self.have_position = False
                self.entry_index = None
                return CLOSE_POSITION, rule_triggered
        
        return NO_EVENT, None
    
    def check_rules(self, data, current_index, rules):
        # logical OR on all the rules
        for rule in rules:
            if rule.f(data, rule.ref, self.entry_index, current_index):
                return rule.name
        return False

# %%
class BackTest():
    
    def __init__(self, raw_data, strategies):
        
        # class data
        self.data = raw_data
        self.trade_record = pd.DataFrame()
        self.report = pd.DataFrame()
        self.strategies = strategies
        self.all_ti_param = list()
        
        # service
        self.cleaner = DataCleaner()
        self.ti_engine = TechIndicatorEngine()
        
    def initialize(self):
        self.initialize_trade_record()
        self.initialize_report()
        self.initialize_all_ti_param()
        print('[BACKTEST] Initializated')
    
    def initialize_trade_record(self):
        self.trade_record = pd.DataFrame()
        self.trade_record['date'] = None
        self.trade_record['strategy_name'] = None
        self.trade_record['position'] = None
        self.trade_record['event'] = None
        self.trade_record['rule'] = None
        self.trade_record['price'] = None
        self.trade_record['trade_return'] = None
        
    def initialize_report(self):
        self.report = pd.DataFrame()
        self.report['strategy_name'] = None
        self.report['occurrence'] = None
        self.report['occ_profit'] = None
        self.report['occ_loss'] = None
        self.report['return_average'] = None
        self.report['return_std'] = None
        
    def initialize_all_ti_param(self):
        for strategy in self.strategies:
            for rule in (strategy.open_position.rules + strategy.close_position.rules):
                for param in rule.indicators_param:
                    
                    if param.name not in self.data.columns:
                        if not self.object_list_contains_object(self.all_ti_param, param):
                            
                            name = self.make_name([i.name for i in self.all_ti_param], param.name)
                            rule.ref[param.name] = name
                            param.name = name
                            self.all_ti_param.append(param)
                        
    @staticmethod
    def object_list_contains_object(obj_list, obj):
        for obj_temp in obj_list:
            if obj_temp == obj:
                return True
        return False
    
    @staticmethod
    def make_name(name_list, target):
        if target not in name_list:
            return target
        i = 2
        while(True):
            new_name = target + '_{}'.format(i)
            if new_name not in name_list:
                return new_name
            i += 1
    
    def data_preprocess(self):
        self.data = self.cleaner.clean(self.data)
        print('[BACKTEST] Finished data pre-process')
        
    def compute_technical_indicator(self):
        for param in self.all_ti_param:
            self.data = self.ti_engine.compute(self.data, param)
        print('[BACKTEST] Finished computation on technical indicators')
        
    def back_test(self):
        for i in self.data.index:
            for strategy in self.strategies:
                event, rule = strategy.check_event(self.data, i)
                if event is not NO_EVENT:
                    date = self.data.at[i, DATE]
                    price = self.data.at[i, CLOSE]
                    self.record_event(date, strategy, event, rule, price)
        self.calculate_return()
        print('[BACKTEST] Finished all backtest')
    
    def record_event(self, date, strategy, event, rule, price):
        new_row = {'date': date,
                   'strategy_name': strategy.name,
                   'position': strategy.position,
                   'event': event,
                   'rule': rule,
                   'price': price}
        self.trade_record = self.trade_record.append(new_row, ignore_index=True)
        
    def calculate_return(self):
        self.trade_record.loc[self.trade_record['event'] == OPEN_POSITION, 'trade_return'] = np.NaN
        
        for strategy in self.strategies:
            
            strategy_trade_record = self.trade_record[self.trade_record['strategy_name'] == strategy.name]
            strategy_trade_record['original_id'] = strategy_trade_record.index
            strategy_trade_record = strategy_trade_record.reset_index()
            
            for i in strategy_trade_record.index:
                
                if strategy_trade_record.at[i, 'event'] == CLOSE_POSITION:
                    date = strategy_trade_record.at[i, DATE]
                    entry_price = strategy_trade_record.at[i-1, 'price']
                    exit_price = strategy_trade_record.at[i, 'price']
                    trade_return = self.compute_return(entry_price, exit_price, strategy.position)
                    original_id = strategy_trade_record.at[i, 'original_id']
                    self.trade_record.at[original_id, 'trade_return'] = trade_return
                    
    @staticmethod
    def compute_return(entry_price, exit_price, position):
        if position == BULLISH:
            return (exit_price - entry_price) / entry_price
        elif position == BEARISH:
            return -1 * (exit_price - entry_price) / entry_price
        else:
            raise ValueError('[ERROR] Unknown Position')
    
    def gen_report(self):
        for strategy in self.strategies:
            df = self.trade_record[self.trade_record['strategy_name'] == strategy.name]
            
            occurrence = df[df['event'] == CLOSE_POSITION].shape[0]
            occ_profit = df[df['trade_return'] > 0].shape[0]
            occ_loss = df[df['trade_return'] < 0].shape[0]
            return_average = df['trade_return'].mean()
            return_std = df['trade_return'].std()
            
            new_row = {'strategy_name': strategy.name,
                       'occurrence': occurrence,
                       'occ_profit': occ_profit,
                       'occ_loss': occ_loss,
                       'return_average': '{:.4%}'.format(return_average),
                       'return_std': return_std}
            self.report = self.report.append(new_row, ignore_index=True)
            
        self.gen_report_summary_row()
        print('[BACKTEST] Generated back test report')
        
    def gen_report_summary_row(self):
        new_row = {'strategy_name': 'summary',
                   'occurrence': self.report['occurrence'].sum(),
                   'occ_profit': self.report['occ_profit'].sum(),
                   'occ_loss': self.report['occ_loss'].sum(),
                   'return_average': '{:.4%}'.format(self.trade_record['trade_return'].mean()),
                   'return_std': self.trade_record['trade_return'].std()}
        self.report = self.report.append(new_row, ignore_index=True)
    
    def run(self):
        self.initialize()
        self.data_preprocess()
        self.compute_technical_indicator()
        self.back_test()
        self.gen_report()
        return

# %%
rule = Rule(name = 'basic', 
            indicators_param = [CCIParam(20, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < -198)
open_position_param = OpenPositionParam(rules=[rule])

rule = Rule(name = 'basic', 
            indicators_param = [CCIParam(20, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > 150)
rule_stop_loss = Rule(name = 'stop_loss', 
                      indicators_param = [IndicatorParam(CLOSE)], 
                      ref = {CLOSE: CLOSE}, 
                      f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] < -0.05)
close_position_param = ClosePositionParam(rules=[rule])

CCI_bull_strategy = Strategy('CCI_bull_strategy', open_position_param, close_position_param, BULLISH)


rule = Rule(name = 'basic', 
            indicators_param = [CCIParam(20, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > 150)
open_position_param = OpenPositionParam(rules=[rule])

rule = Rule(name = 'basic', 
            indicators_param = [CCIParam(20, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < -198)
rule_stop_loss = Rule(name = 'stop_loss', 
                      indicators_param = [IndicatorParam(CLOSE)], 
                      ref = {CLOSE: CLOSE}, 
                      f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] > 0.05)
close_position_param = ClosePositionParam(rules=[rule, rule_stop_loss])

CCI_bear_strategy = Strategy('CCI_bear_strategy', open_position_param, close_position_param, BEARISH)



df = df = pd.read_csv('hsi.csv')
strategies = [CCI_bull_strategy, CCI_bear_strategy]
backtest = BackTest(df, strategies)
backtest.run()
# Out:
# [BACKTEST] Initializated
# [CLEAN] Copy data (2001-09-28, open) to (2001-10-01, open))
# [CLEAN] Copy data (2001-10-01, open) to (2001-10-02, open))
# [CLEAN] Copy data (2001-12-24, open) to (2001-12-25, open))
# [CLEAN] Copy data (2001-12-25, open) to (2001-12-26, open))
# [CLEAN] Copy data (2001-12-31, open) to (2002-01-01, open))
# [CLEAN] Copy data (2002-02-11, open) to (2002-02-12, open))
# [CLEAN] Copy data (2002-02-12, open) to (2002-02-13, open))
# [CLEAN] Copy data (2002-02-13, open) to (2002-02-14, open))
# [CLEAN] Copy data (2002-03-28, open) to (2002-03-29, open))
# [CLEAN] Copy data (2002-03-29, open) to (2002-04-01, open))
# [CLEAN] Copy data (2002-04-04, open) to (2002-04-05, open))
# [CLEAN] Copy data (2002-04-30, open) to (2002-05-01, open))
# [CLEAN] Copy data (2002-05-17, open) to (2002-05-20, open))
# [CLEAN] Copy data (2002-06-28, open) to (2002-07-01, open))
# [CLEAN] Copy data (2002-09-30, open) to (2002-10-01, open))
# [CLEAN] Copy data (2002-10-11, open) to (2002-10-14, open))
# [CLEAN] Copy data (2002-12-24, open) to (2002-12-25, open))
# [CLEAN] Copy data (2002-12-25, open) to (2002-12-26, open))
# [CLEAN] Copy data (2002-12-31, open) to (2003-01-01, open))
# [CLEAN] Copy data (2003-01-30, open) to (2003-01-31, open))
# [CLEAN] Copy data (2003-01-31, open) to (2003-02-03, open))
# [CLEAN] Copy data (2003-04-17, open) to (2003-04-18, open))
# [CLEAN] Copy data (2003-04-18, open) to (2003-04-21, open))
# [CLEAN] Copy data (2003-04-30, open) to (2003-05-01, open))
# [CLEAN] Copy data (2003-05-07, open) to (2003-05-08, open))
# [CLEAN] Copy data (2003-06-03, open) to (2003-06-04, open))
# [CLEAN] Copy data (2003-06-30, open) to (2003-07-01, open))
# [CLEAN] Copy data (2003-09-11, open) to (2003-09-12, open))
# [CLEAN] Copy data (2003-09-30, open) to (2003-10-01, open))
# [CLEAN] Copy data (2003-12-24, open) to (2003-12-25, open))
# [CLEAN] Copy data (2003-12-25, open) to (2003-12-26, open))
# [CLEAN] Copy data (2003-12-31, open) to (2004-01-01, open))
# [CLEAN] Copy data (2004-01-21, open) to (2004-01-22, open))
# [CLEAN] Copy data (2004-01-22, open) to (2004-01-23, open))
# [CLEAN] Copy data (2004-04-02, open) to (2004-04-05, open))
# [CLEAN] Copy data (2004-04-08, open) to (2004-04-09, open))
# [CLEAN] Copy data (2004-04-09, open) to (2004-04-12, open))
# [CLEAN] Copy data (2004-05-25, open) to (2004-05-26, open))
# [CLEAN] Copy data (2004-06-21, open) to (2004-06-22, open))
# [CLEAN] Copy data (2004-06-30, open) to (2004-07-01, open))
# [CLEAN] Copy data (2004-09-28, open) to (2004-09-29, open))
# [CLEAN] Copy data (2004-09-30, open) to (2004-10-01, open))
# [CLEAN] Copy data (2004-10-21, open) to (2004-10-22, open))
# [CLEAN] Copy data (2004-12-24, open) to (2004-12-27, open))
# [CLEAN] Copy data (2008-08-05, open) to (2008-08-06, open))
# [CLEAN] Copy data (2009-12-23, open) to (2009-12-24, open))
# [CLEAN] Copy data (2009-12-30, open) to (2009-12-31, open))
# [CLEAN] Copy data (2010-12-23, open) to (2010-12-24, open))
# [CLEAN] Copy data (2010-12-30, open) to (2010-12-31, open))
# [CLEAN] Copy data (2011-02-01, open) to (2011-02-02, open))
# [CLEAN] Copy data (2011-12-23, open) to (2011-12-24, open))
# [CLEAN] Copy data (2011-12-30, open) to (2011-12-31, open))
# [CLEAN] Copy data (2012-12-21, open) to (2012-12-24, open))
# [CLEAN] Copy data (2012-12-28, open) to (2012-12-31, open))
# [CLEAN] Copy data (2013-08-13, open) to (2013-08-14, open))
# [CLEAN] Copy data (2016-08-01, open) to (2016-08-02, open))
# [CLEAN] Copy data (2016-10-20, open) to (2016-10-21, open))
# [CLEAN] Copy data (2017-08-22, open) to (2017-08-23, open))
# [CLEAN] Copy data (2020-10-12, open) to (2020-10-13, open))
# [CLEAN] Copy data (2001-09-28, high) to (2001-10-01, high))
# [CLEAN] Copy data (2001-10-01, high) to (2001-10-02, high))
# [CLEAN] Copy data (2001-12-24, high) to (2001-12-25, high))
# [CLEAN] Copy data (2001-12-25, high) to (2001-12-26, high))
# [CLEAN] Copy data (2001-12-31, high) to (2002-01-01, high))
# [CLEAN] Copy data (2002-02-11, high) to (2002-02-12, high))
# [CLEAN] Copy data (2002-02-12, high) to (2002-02-13, high))
# [CLEAN] Copy data (2002-02-13, high) to (2002-02-14, high))
# [CLEAN] Copy data (2002-03-28, high) to (2002-03-29, high))
# [CLEAN] Copy data (2002-03-29, high) to (2002-04-01, high))
# [CLEAN] Copy data (2002-04-04, high) to (2002-04-05, high))
# [CLEAN] Copy data (2002-04-30, high) to (2002-05-01, high))
# [CLEAN] Copy data (2002-05-17, high) to (2002-05-20, high))
# [CLEAN] Copy data (2002-06-28, high) to (2002-07-01, high))
# [CLEAN] Copy data (2002-09-30, high) to (2002-10-01, high))
# [CLEAN] Copy data (2002-10-11, high) to (2002-10-14, high))
# [CLEAN] Copy data (2002-12-24, high) to (2002-12-25, high))
# [CLEAN] Copy data (2002-12-25, high) to (2002-12-26, high))
# [CLEAN] Copy data (2002-12-31, high) to (2003-01-01, high))
# [CLEAN] Copy data (2003-01-30, high) to (2003-01-31, high))
# [CLEAN] Copy data (2003-01-31, high) to (2003-02-03, high))
# [CLEAN] Copy data (2003-04-17, high) to (2003-04-18, high))
# [CLEAN] Copy data (2003-04-18, high) to (2003-04-21, high))
# [CLEAN] Copy data (2003-04-30, high) to (2003-05-01, high))
# [CLEAN] Copy data (2003-05-07, high) to (2003-05-08, high))
# [CLEAN] Copy data (2003-06-03, high) to (2003-06-04, high))
# [CLEAN] Copy data (2003-06-30, high) to (2003-07-01, high))
# [CLEAN] Copy data (2003-09-11, high) to (2003-09-12, high))
# [CLEAN] Copy data (2003-09-30, high) to (2003-10-01, high))
# [CLEAN] Copy data (2003-12-24, high) to (2003-12-25, high))
# [CLEAN] Copy data (2003-12-25, high) to (2003-12-26, high))
# [CLEAN] Copy data (2003-12-31, high) to (2004-01-01, high))
# [CLEAN] Copy data (2004-01-21, high) to (2004-01-22, high))
# [CLEAN] Copy data (2004-01-22, high) to (2004-01-23, high))
# [CLEAN] Copy data (2004-04-02, high) to (2004-04-05, high))
# [CLEAN] Copy data (2004-04-08, high) to (2004-04-09, high))
# [CLEAN] Copy data (2004-04-09, high) to (2004-04-12, high))
# [CLEAN] Copy data (2004-05-25, high) to (2004-05-26, high))
# [CLEAN] Copy data (2004-06-21, high) to (2004-06-22, high))
# [CLEAN] Copy data (2004-06-30, high) to (2004-07-01, high))
# [CLEAN] Copy data (2004-09-28, high) to (2004-09-29, high))
# [CLEAN] Copy data (2004-09-30, high) to (2004-10-01, high))
# [CLEAN] Copy data (2004-10-21, high) to (2004-10-22, high))
# [CLEAN] Copy data (2004-12-24, high) to (2004-12-27, high))
# [CLEAN] Copy data (2008-08-05, high) to (2008-08-06, high))
# [CLEAN] Copy data (2009-12-23, high) to (2009-12-24, high))
# [CLEAN] Copy data (2009-12-30, high) to (2009-12-31, high))
# [CLEAN] Copy data (2010-12-23, high) to (2010-12-24, high))
# [CLEAN] Copy data (2010-12-30, high) to (2010-12-31, high))
# [CLEAN] Copy data (2011-02-01, high) to (2011-02-02, high))
# [CLEAN] Copy data (2011-12-23, high) to (2011-12-24, high))
# [CLEAN] Copy data (2011-12-30, high) to (2011-12-31, high))
# [CLEAN] Copy data (2012-12-21, high) to (2012-12-24, high))
# [CLEAN] Copy data (2012-12-28, high) to (2012-12-31, high))
# [CLEAN] Copy data (2013-08-13, high) to (2013-08-14, high))
# [CLEAN] Copy data (2016-08-01, high) to (2016-08-02, high))
# [CLEAN] Copy data (2016-10-20, high) to (2016-10-21, high))
# [CLEAN] Copy data (2017-08-22, high) to (2017-08-23, high))
# [CLEAN] Copy data (2020-10-12, high) to (2020-10-13, high))
# [CLEAN] Copy data (2001-09-28, low) to (2001-10-01, low))
# [CLEAN] Copy data (2001-10-01, low) to (2001-10-02, low))
# [CLEAN] Copy data (2001-12-24, low) to (2001-12-25, low))
# [CLEAN] Copy data (2001-12-25, low) to (2001-12-26, low))
# [CLEAN] Copy data (2001-12-31, low) to (2002-01-01, low))
# [CLEAN] Copy data (2002-02-11, low) to (2002-02-12, low))
# [CLEAN] Copy data (2002-02-12, low) to (2002-02-13, low))
# [CLEAN] Copy data (2002-02-13, low) to (2002-02-14, low))
# [CLEAN] Copy data (2002-03-28, low) to (2002-03-29, low))
# [CLEAN] Copy data (2002-03-29, low) to (2002-04-01, low))
# [CLEAN] Copy data (2002-04-04, low) to (2002-04-05, low))
# [CLEAN] Copy data (2002-04-30, low) to (2002-05-01, low))
# [CLEAN] Copy data (2002-05-17, low) to (2002-05-20, low))
# [CLEAN] Copy data (2002-06-28, low) to (2002-07-01, low))
# [CLEAN] Copy data (2002-09-30, low) to (2002-10-01, low))
# [CLEAN] Copy data (2002-10-11, low) to (2002-10-14, low))
# [CLEAN] Copy data (2002-12-24, low) to (2002-12-25, low))
# [CLEAN] Copy data (2002-12-25, low) to (2002-12-26, low))
# [CLEAN] Copy data (2002-12-31, low) to (2003-01-01, low))
# [CLEAN] Copy data (2003-01-30, low) to (2003-01-31, low))
# [CLEAN] Copy data (2003-01-31, low) to (2003-02-03, low))
# [CLEAN] Copy data (2003-04-17, low) to (2003-04-18, low))
# [CLEAN] Copy data (2003-04-18, low) to (2003-04-21, low))
# [CLEAN] Copy data (2003-04-30, low) to (2003-05-01, low))
# [CLEAN] Copy data (2003-05-07, low) to (2003-05-08, low))
# [CLEAN] Copy data (2003-06-03, low) to (2003-06-04, low))
# [CLEAN] Copy data (2003-06-30, low) to (2003-07-01, low))
# [CLEAN] Copy data (2003-09-11, low) to (2003-09-12, low))
# [CLEAN] Copy data (2003-09-30, low) to (2003-10-01, low))
# [CLEAN] Copy data (2003-12-24, low) to (2003-12-25, low))
# [CLEAN] Copy data (2003-12-25, low) to (2003-12-26, low))
# [CLEAN] Copy data (2003-12-31, low) to (2004-01-01, low))
# [CLEAN] Copy data (2004-01-21, low) to (2004-01-22, low))
# [CLEAN] Copy data (2004-01-22, low) to (2004-01-23, low))
# [CLEAN] Copy data (2004-04-02, low) to (2004-04-05, low))
# [CLEAN] Copy data (2004-04-08, low) to (2004-04-09, low))
# [CLEAN] Copy data (2004-04-09, low) to (2004-04-12, low))
# [CLEAN] Copy data (2004-05-25, low) to (2004-05-26, low))
# [CLEAN] Copy data (2004-06-21, low) to (2004-06-22, low))
# [CLEAN] Copy data (2004-06-30, low) to (2004-07-01, low))
# [CLEAN] Copy data (2004-09-28, low) to (2004-09-29, low))
# [CLEAN] Copy data (2004-09-30, low) to (2004-10-01, low))
# [CLEAN] Copy data (2004-10-21, low) to (2004-10-22, low))
# [CLEAN] Copy data (2004-12-24, low) to (2004-12-27, low))
# [CLEAN] Copy data (2008-08-05, low) to (2008-08-06, low))
# [CLEAN] Copy data (2009-12-23, low) to (2009-12-24, low))
# [CLEAN] Copy data (2009-12-30, low) to (2009-12-31, low))
# [CLEAN] Copy data (2010-12-23, low) to (2010-12-24, low))
# [CLEAN] Copy data (2010-12-30, low) to (2010-12-31, low))
# [CLEAN] Copy data (2011-02-01, low) to (2011-02-02, low))
# [CLEAN] Copy data (2011-12-23, low) to (2011-12-24, low))
# [CLEAN] Copy data (2011-12-30, low) to (2011-12-31, low))
# [CLEAN] Copy data (2012-12-21, low) to (2012-12-24, low))
# [CLEAN] Copy data (2012-12-28, low) to (2012-12-31, low))
# [CLEAN] Copy data (2013-08-13, low) to (2013-08-14, low))
# [CLEAN] Copy data (2016-08-01, low) to (2016-08-02, low))
# [CLEAN] Copy data (2016-10-20, low) to (2016-10-21, low))
# [CLEAN] Copy data (2017-08-22, low) to (2017-08-23, low))
# [CLEAN] Copy data (2020-10-12, low) to (2020-10-13, low))
# [CLEAN] Copy data (2001-09-28, close) to (2001-10-01, close))
# [CLEAN] Copy data (2001-10-01, close) to (2001-10-02, close))
# [CLEAN] Copy data (2001-12-24, close) to (2001-12-25, close))
# [CLEAN] Copy data (2001-12-25, close) to (2001-12-26, close))
# [CLEAN] Copy data (2001-12-31, close) to (2002-01-01, close))
# [CLEAN] Copy data (2002-02-11, close) to (2002-02-12, close))
# [CLEAN] Copy data (2002-02-12, close) to (2002-02-13, close))
# [CLEAN] Copy data (2002-02-13, close) to (2002-02-14, close))
# [CLEAN] Copy data (2002-03-28, close) to (2002-03-29, close))
# [CLEAN] Copy data (2002-03-29, close) to (2002-04-01, close))
# [CLEAN] Copy data (2002-04-04, close) to (2002-04-05, close))
# [CLEAN] Copy data (2002-04-30, close) to (2002-05-01, close))
# [CLEAN] Copy data (2002-05-17, close) to (2002-05-20, close))
# [CLEAN] Copy data (2002-06-28, close) to (2002-07-01, close))
# [CLEAN] Copy data (2002-09-30, close) to (2002-10-01, close))
# [CLEAN] Copy data (2002-10-11, close) to (2002-10-14, close))
# [CLEAN] Copy data (2002-12-24, close) to (2002-12-25, close))
# [CLEAN] Copy data (2002-12-25, close) to (2002-12-26, close))
# [CLEAN] Copy data (2002-12-31, close) to (2003-01-01, close))
# [CLEAN] Copy data (2003-01-30, close) to (2003-01-31, close))
# [CLEAN] Copy data (2003-01-31, close) to (2003-02-03, close))
# [CLEAN] Copy data (2003-04-17, close) to (2003-04-18, close))
# [CLEAN] Copy data (2003-04-18, close) to (2003-04-21, close))
# [CLEAN] Copy data (2003-04-30, close) to (2003-05-01, close))
# [CLEAN] Copy data (2003-05-07, close) to (2003-05-08, close))
# [CLEAN] Copy data (2003-06-03, close) to (2003-06-04, close))
# [CLEAN] Copy data (2003-06-30, close) to (2003-07-01, close))
# [CLEAN] Copy data (2003-09-11, close) to (2003-09-12, close))
# [CLEAN] Copy data (2003-09-30, close) to (2003-10-01, close))
# [CLEAN] Copy data (2003-12-24, close) to (2003-12-25, close))
# [CLEAN] Copy data (2003-12-25, close) to (2003-12-26, close))
# [CLEAN] Copy data (2003-12-31, close) to (2004-01-01, close))
# [CLEAN] Copy data (2004-01-21, close) to (2004-01-22, close))
# [CLEAN] Copy data (2004-01-22, close) to (2004-01-23, close))
# [CLEAN] Copy data (2004-04-02, close) to (2004-04-05, close))
# [CLEAN] Copy data (2004-04-08, close) to (2004-04-09, close))
# [CLEAN] Copy data (2004-04-09, close) to (2004-04-12, close))
# [CLEAN] Copy data (2004-05-25, close) to (2004-05-26, close))
# [CLEAN] Copy data (2004-06-21, close) to (2004-06-22, close))
# [CLEAN] Copy data (2004-06-30, close) to (2004-07-01, close))
# [CLEAN] Copy data (2004-09-28, close) to (2004-09-29, close))
# [CLEAN] Copy data (2004-09-30, close) to (2004-10-01, close))
# [CLEAN] Copy data (2004-10-21, close) to (2004-10-22, close))
# [CLEAN] Copy data (2004-12-24, close) to (2004-12-27, close))
# [CLEAN] Copy data (2008-08-05, close) to (2008-08-06, close))
# [CLEAN] Copy data (2009-12-23, close) to (2009-12-24, close))
# [CLEAN] Copy data (2009-12-30, close) to (2009-12-31, close))
# [CLEAN] Copy data (2010-12-23, close) to (2010-12-24, close))
# [CLEAN] Copy data (2010-12-30, close) to (2010-12-31, close))
# [CLEAN] Copy data (2011-02-01, close) to (2011-02-02, close))
# [CLEAN] Copy data (2011-12-23, close) to (2011-12-24, close))
# [CLEAN] Copy data (2011-12-30, close) to (2011-12-31, close))
# [CLEAN] Copy data (2012-12-21, close) to (2012-12-24, close))
# [CLEAN] Copy data (2012-12-28, close) to (2012-12-31, close))
# [CLEAN] Copy data (2013-08-13, close) to (2013-08-14, close))
# [CLEAN] Copy data (2016-08-01, close) to (2016-08-02, close))
# [CLEAN] Copy data (2016-10-20, close) to (2016-10-21, close))
# [CLEAN] Copy data (2017-08-22, close) to (2017-08-23, close))
# [CLEAN] Copy data (2020-10-12, close) to (2020-10-13, close))
# [CLEAN] Copy data (2001-09-28, adj_close) to (2001-10-01, adj_close))
# [CLEAN] Copy data (2001-10-01, adj_close) to (2001-10-02, adj_close))
# [CLEAN] Copy data (2001-12-24, adj_close) to (2001-12-25, adj_close))
# [CLEAN] Copy data (2001-12-25, adj_close) to (2001-12-26, adj_close))
# [CLEAN] Copy data (2001-12-31, adj_close) to (2002-01-01, adj_close))
# [CLEAN] Copy data (2002-02-11, adj_close) to (2002-02-12, adj_close))
# [CLEAN] Copy data (2002-02-12, adj_close) to (2002-02-13, adj_close))
# [CLEAN] Copy data (2002-02-13, adj_close) to (2002-02-14, adj_close))
# [CLEAN] Copy data (2002-03-28, adj_close) to (2002-03-29, adj_close))
# [CLEAN] Copy data (2002-03-29, adj_close) to (2002-04-01, adj_close))
# [CLEAN] Copy data (2002-04-04, adj_close) to (2002-04-05, adj_close))
# [CLEAN] Copy data (2002-04-30, adj_close) to (2002-05-01, adj_close))
# [CLEAN] Copy data (2002-05-17, adj_close) to (2002-05-20, adj_close))
# [CLEAN] Copy data (2002-06-28, adj_close) to (2002-07-01, adj_close))
# [CLEAN] Copy data (2002-09-30, adj_close) to (2002-10-01, adj_close))
# [CLEAN] Copy data (2002-10-11, adj_close) to (2002-10-14, adj_close))
# [CLEAN] Copy data (2002-12-24, adj_close) to (2002-12-25, adj_close))
# [CLEAN] Copy data (2002-12-25, adj_close) to (2002-12-26, adj_close))
# [CLEAN] Copy data (2002-12-31, adj_close) to (2003-01-01, adj_close))
# [CLEAN] Copy data (2003-01-30, adj_close) to (2003-01-31, adj_close))
# [CLEAN] Copy data (2003-01-31, adj_close) to (2003-02-03, adj_close))
# [CLEAN] Copy data (2003-04-17, adj_close) to (2003-04-18, adj_close))
# [CLEAN] Copy data (2003-04-18, adj_close) to (2003-04-21, adj_close))
# [CLEAN] Copy data (2003-04-30, adj_close) to (2003-05-01, adj_close))
# [CLEAN] Copy data (2003-05-07, adj_close) to (2003-05-08, adj_close))
# [CLEAN] Copy data (2003-06-03, adj_close) to (2003-06-04, adj_close))
# [CLEAN] Copy data (2003-06-30, adj_close) to (2003-07-01, adj_close))
# [CLEAN] Copy data (2003-09-11, adj_close) to (2003-09-12, adj_close))
# [CLEAN] Copy data (2003-09-30, adj_close) to (2003-10-01, adj_close))
# [CLEAN] Copy data (2003-12-24, adj_close) to (2003-12-25, adj_close))
# [CLEAN] Copy data (2003-12-25, adj_close) to (2003-12-26, adj_close))
# [CLEAN] Copy data (2003-12-31, adj_close) to (2004-01-01, adj_close))
# [CLEAN] Copy data (2004-01-21, adj_close) to (2004-01-22, adj_close))
# [CLEAN] Copy data (2004-01-22, adj_close) to (2004-01-23, adj_close))
# [CLEAN] Copy data (2004-04-02, adj_close) to (2004-04-05, adj_close))
# [CLEAN] Copy data (2004-04-08, adj_close) to (2004-04-09, adj_close))
# [CLEAN] Copy data (2004-04-09, adj_close) to (2004-04-12, adj_close))
# [CLEAN] Copy data (2004-05-25, adj_close) to (2004-05-26, adj_close))
# [CLEAN] Copy data (2004-06-21, adj_close) to (2004-06-22, adj_close))
# [CLEAN] Copy data (2004-06-30, adj_close) to (2004-07-01, adj_close))
# [CLEAN] Copy data (2004-09-28, adj_close) to (2004-09-29, adj_close))
# [CLEAN] Copy data (2004-09-30, adj_close) to (2004-10-01, adj_close))
# [CLEAN] Copy data (2004-10-21, adj_close) to (2004-10-22, adj_close))
# [CLEAN] Copy data (2004-12-24, adj_close) to (2004-12-27, adj_close))
# [CLEAN] Copy data (2008-08-05, adj_close) to (2008-08-06, adj_close))
# [CLEAN] Copy data (2009-12-23, adj_close) to (2009-12-24, adj_close))
# [CLEAN] Copy data (2009-12-30, adj_close) to (2009-12-31, adj_close))
# [CLEAN] Copy data (2010-12-23, adj_close) to (2010-12-24, adj_close))
# [CLEAN] Copy data (2010-12-30, adj_close) to (2010-12-31, adj_close))
# [CLEAN] Copy data (2011-02-01, adj_close) to (2011-02-02, adj_close))
# [CLEAN] Copy data (2011-12-23, adj_close) to (2011-12-24, adj_close))
# [CLEAN] Copy data (2011-12-30, adj_close) to (2011-12-31, adj_close))
# [CLEAN] Copy data (2012-12-21, adj_close) to (2012-12-24, adj_close))
# [CLEAN] Copy data (2012-12-28, adj_close) to (2012-12-31, adj_close))
# [CLEAN] Copy data (2013-08-13, adj_close) to (2013-08-14, adj_close))
# [CLEAN] Copy data (2016-08-01, adj_close) to (2016-08-02, adj_close))
# [CLEAN] Copy data (2016-10-20, adj_close) to (2016-10-21, adj_close))
# [CLEAN] Copy data (2017-08-22, adj_close) to (2017-08-23, adj_close))
# [CLEAN] Copy data (2020-10-12, adj_close) to (2020-10-13, adj_close))
# [CLEAN] Copy data (2001-09-28, volume) to (2001-10-01, volume))
# [CLEAN] Copy data (2001-10-01, volume) to (2001-10-02, volume))
# [CLEAN] Copy data (2001-10-24, volume) to (2001-10-25, volume))
# [CLEAN] Copy data (2001-12-24, volume) to (2001-12-25, volume))
# [CLEAN] Copy data (2001-12-25, volume) to (2001-12-26, volume))
# [CLEAN] Copy data (2001-12-31, volume) to (2002-01-01, volume))
# [CLEAN] Copy data (2002-02-11, volume) to (2002-02-12, volume))
# [CLEAN] Copy data (2002-02-12, volume) to (2002-02-13, volume))
# [CLEAN] Copy data (2002-02-13, volume) to (2002-02-14, volume))
# [CLEAN] Copy data (2002-03-28, volume) to (2002-03-29, volume))
# [CLEAN] Copy data (2002-03-29, volume) to (2002-04-01, volume))
# [CLEAN] Copy data (2002-04-04, volume) to (2002-04-05, volume))
# [CLEAN] Copy data (2002-04-30, volume) to (2002-05-01, volume))
# [CLEAN] Copy data (2002-05-17, volume) to (2002-05-20, volume))
# [CLEAN] Copy data (2002-06-28, volume) to (2002-07-01, volume))
# [CLEAN] Copy data (2002-09-30, volume) to (2002-10-01, volume))
# [CLEAN] Copy data (2002-10-11, volume) to (2002-10-14, volume))
# [CLEAN] Copy data (2002-12-24, volume) to (2002-12-25, volume))
# [CLEAN] Copy data (2002-12-25, volume) to (2002-12-26, volume))
# [CLEAN] Copy data (2002-12-31, volume) to (2003-01-01, volume))
# [CLEAN] Copy data (2003-01-30, volume) to (2003-01-31, volume))
# [CLEAN] Copy data (2003-01-31, volume) to (2003-02-03, volume))
# [CLEAN] Copy data (2003-04-17, volume) to (2003-04-18, volume))
# [CLEAN] Copy data (2003-04-18, volume) to (2003-04-21, volume))
# [CLEAN] Copy data (2003-04-30, volume) to (2003-05-01, volume))
# [CLEAN] Copy data (2003-05-07, volume) to (2003-05-08, volume))
# [CLEAN] Copy data (2003-06-03, volume) to (2003-06-04, volume))
# [CLEAN] Copy data (2003-06-30, volume) to (2003-07-01, volume))
# [CLEAN] Copy data (2003-09-11, volume) to (2003-09-12, volume))
# [CLEAN] Copy data (2003-09-30, volume) to (2003-10-01, volume))
# [CLEAN] Copy data (2003-12-24, volume) to (2003-12-25, volume))
# [CLEAN] Copy data (2003-12-25, volume) to (2003-12-26, volume))
# [CLEAN] Copy data (2003-12-31, volume) to (2004-01-01, volume))
# [CLEAN] Copy data (2004-01-21, volume) to (2004-01-22, volume))
# [CLEAN] Copy data (2004-01-22, volume) to (2004-01-23, volume))
# [CLEAN] Copy data (2004-04-02, volume) to (2004-04-05, volume))
# [CLEAN] Copy data (2004-04-08, volume) to (2004-04-09, volume))
# [CLEAN] Copy data (2004-04-09, volume) to (2004-04-12, volume))
# [CLEAN] Copy data (2004-05-25, volume) to (2004-05-26, volume))
# [CLEAN] Copy data (2004-06-21, volume) to (2004-06-22, volume))
# [CLEAN] Copy data (2004-06-30, volume) to (2004-07-01, volume))
# [CLEAN] Copy data (2004-09-28, volume) to (2004-09-29, volume))
# [CLEAN] Copy data (2004-09-30, volume) to (2004-10-01, volume))
# [CLEAN] Copy data (2004-10-21, volume) to (2004-10-22, volume))
# [CLEAN] Copy data (2004-12-24, volume) to (2004-12-27, volume))
# [CLEAN] Copy data (2006-12-22, volume) to (2006-12-27, volume))
# [CLEAN] Copy data (2007-03-15, volume) to (2007-03-16, volume))
# [CLEAN] Copy data (2007-05-28, volume) to (2007-05-29, volume))
# [CLEAN] Copy data (2008-08-05, volume) to (2008-08-06, volume))
# [CLEAN] Copy data (2008-08-21, volume) to (2008-08-22, volume))
# [CLEAN] Copy data (2009-11-09, volume) to (2009-11-10, volume))
# [CLEAN] Copy data (2009-12-23, volume) to (2009-12-24, volume))
# [CLEAN] Copy data (2009-12-30, volume) to (2009-12-31, volume))
# [CLEAN] Copy data (2010-12-23, volume) to (2010-12-24, volume))
# [CLEAN] Copy data (2010-12-30, volume) to (2010-12-31, volume))
# [CLEAN] Copy data (2011-02-01, volume) to (2011-02-02, volume))
# [CLEAN] Copy data (2011-12-23, volume) to (2011-12-24, volume))
# [CLEAN] Copy data (2011-12-30, volume) to (2011-12-31, volume))
# [CLEAN] Copy data (2012-12-21, volume) to (2012-12-24, volume))
# [CLEAN] Copy data (2012-12-28, volume) to (2012-12-31, volume))
# [CLEAN] Copy data (2013-08-13, volume) to (2013-08-14, volume))
# [CLEAN] Copy data (2016-08-01, volume) to (2016-08-02, volume))
# [CLEAN] Copy data (2016-10-20, volume) to (2016-10-21, volume))
# [CLEAN] Copy data (2017-08-22, volume) to (2017-08-23, volume))
# [CLEAN] Copy data (2019-03-11, volume) to (2019-03-12, volume))
# [CLEAN] Copy data (2019-12-17, volume) to (2019-12-18, volume))
# [CLEAN] Copy data (2020-02-25, volume) to (2020-02-26, volume))
# [CLEAN] Copy data (2020-03-20, volume) to (2020-03-23, volume))
# [CLEAN] Copy data (2020-05-05, volume) to (2020-05-06, volume))
# [CLEAN] Copy data (2020-07-22, volume) to (2020-07-23, volume))
# [CLEAN] Copy data (2020-10-12, volume) to (2020-10-13, volume))
# [BACKTEST] Finished data pre-process
# [TechIndicatorEngine] Finished computation of CCI
# [BACKTEST] Finished computation on technical indicators
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
backtest.trade_record
# Out:
#            date      strategy_name position           event       rule  \
# 0    2001-11-14  CCI_bear_strategy  bearish   open_position      basic
# 1    2001-11-15  CCI_bear_strategy  bearish  close_position  stop_loss
# 2    2001-11-16  CCI_bear_strategy  bearish   open_position      basic
# 3    2001-12-04  CCI_bear_strategy  bearish  close_position  stop_loss
# 4    2002-03-07  CCI_bear_strategy  bearish   open_position      basic
# ..          ...                ...      ...             ...        ...
# 160  2019-12-13  CCI_bear_strategy  bearish   open_position      basic
# 161  2019-12-27  CCI_bear_strategy  bearish  close_position  stop_loss
# 162  2020-03-09  CCI_bull_strategy  bullish   open_position      basic
# 163  2020-07-06  CCI_bull_strategy  bullish  close_position      basic
# 164  2020-07-06  CCI_bear_strategy  bearish   open_position      basic
#
#            price  trade_return
# 0    10950.04004           NaN
# 1    11239.38965     -0.026425
# 2    11287.37012           NaN
# 3    11427.28027     -0.012395
# 4    11188.07031           NaN
# ..           ...           ...
# 160  27687.75977           NaN
# 161  28225.41992     -0.019419
# 162  25040.46094           NaN
# 163  26339.16016      0.051864
# 164  26339.16016           NaN
#
# [165 rows x 7 columns]

# %%
backtest.report
# Out:
#        strategy_name occurrence occ_profit occ_loss return_average  return_std
# 0  CCI_bull_strategy         14          9        5        3.3106%    0.215840
# 1  CCI_bear_strategy         37          8       29       -2.2747%    0.068630
# 2            summary         51         17       34       -0.7415%    0.127034

# %%
display_df(backtest.trade_record)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>date</th>
#       <th>strategy_name</th>
#       <th>position</th>
#       <th>event</th>
#       <th>rule</th>
#       <th>price</th>
#       <th>trade_return</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2001-11-14</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>10950.040040</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2001-12-05</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>11678.440430</td>
#       <td>-0.066520</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2002-03-07</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>11188.070310</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2002-05-02</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>11780.110350</td>
#       <td>-0.052917</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2003-05-12</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>9155.570313</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2003-06-02</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>9637.530273</td>
#       <td>-0.052641</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2003-08-18</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>10525.040040</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2003-09-03</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>11102.360350</td>
#       <td>-0.054852</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2003-10-03</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>11608.719730</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2003-10-21</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>12250.690430</td>
#       <td>-0.055301</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>2004-01-05</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>13005.330080</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2004-01-21</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>13750.580080</td>
#       <td>-0.057303</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2004-07-21</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>12395.110350</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2004-09-01</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>13023.870120</td>
#       <td>-0.050726</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2004-11-05</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>13494.950200</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2004-12-02</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>14261.790040</td>
#       <td>-0.056824</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2005-01-05</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>13764.360350</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2005-05-05</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>close_position</td>
#       <td>basic</td>
#       <td>14061.700200</td>
#       <td>0.021602</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2005-05-05</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>14061.700200</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2005-07-22</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>14786.459960</td>
#       <td>-0.051541</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2005-09-29</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>15431.250000</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2005-10-06</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>14839.299810</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>2005-10-06</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>basic</td>
#       <td>14839.299810</td>
#       <td>0.038360</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2006-01-05</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>close_position</td>
#       <td>basic</td>
#       <td>15271.129880</td>
#       <td>0.029100</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2006-01-05</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>15271.129880</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>2006-04-03</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>16063.750000</td>
#       <td>-0.051903</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2006-04-04</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>16100.089840</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2006-04-20</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>16944.339840</td>
#       <td>-0.052438</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2006-09-21</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>17619.970700</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2006-11-02</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>18714.779300</td>
#       <td>-0.062135</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>2006-12-27</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>19725.730470</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>2007-01-22</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>close_position</td>
#       <td>stop_loss</td>
#       <td>20772.220700</td>
#       <td>-0.053052</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>2007-02-28</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>19651.509770</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>2007-06-18</td>
#       <td>CCI_bull_strategy</td>
#       <td>bullish</td>
#       <td>close_position</td>
#       <td>basic</td>
#       <td>21582.890630</td>
#       <td>0.098282</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>2007-06-18</td>
#       <td>CCI_bear_strategy</td>
#       <td>bearish</td>
#       <td>open_position</td>
#       <td>basic</td>
#       <td>21582.890630</td>
#       <td>NaN</td>

# %%
# backtest.all_ti_param[1].__dict__
backtest.strategies[0].open_position.rules[0].__dict__
backtest.strategies[0].close_position.rules[0].__dict__
backtest.data
# Out:
#             date          open          high           low         close  \
# 0     2001-09-19   9402.650391   9560.940430   9377.559570   9558.150391
# 1     2001-09-20   9415.099609   9415.099609   9249.160156   9317.980469
# 2     2001-09-21   9039.650391   9039.650391   8894.360352   8934.200195
# 3     2001-09-24   8971.469727   9292.269531   8971.469727   9284.500000
# 4     2001-09-25   9411.349609   9440.269531   9166.120117   9210.059570
# ...          ...           ...           ...           ...           ...
# 4763  2020-10-23  24773.119140  24970.589840  24683.250000  24918.779300
# 4764  2020-10-27  24839.970700  24872.519530  24602.109380  24787.189450
# 4765  2020-10-28  24773.539060  24844.789060  24586.060550  24708.800780
# 4766  2020-10-29  24290.009770  24678.900390  24258.560550  24586.599610
# 4767  2020-10-30  24535.900390  24600.539060  24029.949220  24107.419920
#
#          adj_close        volume        CCI
# 0      9558.150391  3.332562e+08        NaN
# 1      9317.980469  2.849664e+08        NaN
# 2      8934.200195  5.199404e+08        NaN
# 3      9284.500000  4.421815e+08        NaN
# 4      9210.059570  3.675458e+08        NaN
# ...            ...           ...        ...
# 4763  24918.779300  2.368157e+09  85.954159
# 4764  24787.189450  2.435165e+09  69.076830
# 4765  24708.800780  2.011940e+09  58.826598
# 4766  24586.599610  1.936749e+09  24.565798
# 4767  24107.419920  2.537744e+09 -23.857364
#
# [4768 rows x 8 columns]

# %%
TI.CCI.value
# Out:
# 'CCI'
