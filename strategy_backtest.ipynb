# %%
import pandas as pd
import numpy as np
import random
import os.path
from enum import Enum
from IPython.display import display, HTML
from datetime import datetime

from const import *

def display_df(df):
    display(HTML(df.to_html()))

# %%
class DataCleaner():
    
    def __init__(self):
        self.dropna_method = 'all'
        self.is_fill_missing = True
    
    def clean(self, raw_data):
        raw_data = raw_data.dropna(how=self.dropna_method)
        if self.is_fill_missing:
            raw_data = self.fill_missing_date_time(raw_data)
        return raw_data
    
    @staticmethod
    def fill_missing_date_time(raw_data):
        count = 0
        cols = list(raw_data.columns)
        cols.remove(DATE_TIME)
        for col in cols:
            for i in raw_data.index:
                element = raw_data.at[i, col]
                if np.isnan(element) or element == 0:
                    missing_data_date = raw_data.at[i, DATE_TIME]
                    ref_data_date = raw_data.at[i-1, DATE_TIME]
                    raw_data.at[i, col] = raw_data.at[i-1, col]
                    count += 1
#                     print('[CLEAN] Copy data ({}, {}) to ({}, {}))'
#                           .format(ref_data_date, col, missing_data_date, col))
        print('[CLEAN] {} data items are filled'.format(count))
    
        return raw_data

# %%
class TechIndicatorEngine():
    def __init__(self):
        pass
    
    def compute(self, data, ti_param):
        if self.extract_alphabet(ti_param.name) == TI_CCI:
            cci = CCI(ti_param)
            data = cci.compute(data)
        elif self.extract_alphabet(ti_param.name) == TI_SMA:
            sma = SMA(ti_param)
            data = sma.compute(data)
        else:
            raise ValueError('[ERROR] Unknown technical indicator: {}'.format(ti_param.name))
        
        print('[TechIndicatorEngine] Finished computation of {}'.format(ti_param.name))
        return data
    
    @staticmethod
    def extract_alphabet(s):
        return ''.join(x for x in s if x.isalpha())

# %%
class IndicatorParam():
    def __init__(self, name):
        self.name = name
        
    def __eq__(self, other):
        if self.__class__ != other.__class__:
            return False
        return self.__dict__ == other.__dict__


class CCIParam(IndicatorParam):
    def __init__(self, period, coeff):
        super().__init__(TI_CCI)
        self.period = period
        self.coeff = coeff


class SMAParam(IndicatorParam):
    def __init__(self, period, on):
        super().__init__(TI_CCI)
        self.period = period
        self.on = on

# %%
class CCI():
    
    def __init__(self, param):
        self.param = param
        
    def compute(self, data):
        
        # typical price
        data['typical'] = data[[HIGH, LOW, CLOSE]].apply(lambda row: self.typical_price(row), axis=1)
        
        # moving average of typical price
        data['MA'] = data['typical'].rolling(window=self.param.period).mean()
        
        # absolute difference between typical price and MA
        data['abs_diff'] = data[['typical', 'MA']].apply(lambda row: abs(row['typical'] - row['MA']), axis=1)
        
        # mean deviation
        data['MD'] = data['abs_diff'].rolling(window=self.param.period).mean()
        
        # CCI
        data[self.param.name] = data[['typical', 'MA', 'MD']].apply(lambda row: self.cci_formula(row), axis=1)
        
        # drop columns for intermediate steps
        data = data.drop(columns=['typical', 'MA', 'abs_diff', 'MD'])
        
        return data
        
    @staticmethod
    def typical_price(row):
        return (row[HIGH] + row[LOW] + row[CLOSE]) / 3
    
    def cci_formula(self, row):
        return (row['typical'] - row['MA']) / (self.param.coeff * row['MD'])


class SMA():
    
    def __init__(self, param):
        self.param = self.param
        
    def compute(self, data):
        
        data[self.param.name] = data[on].rolling(window=self.param.period).mean()
        
        return data

# %%
class Rule():
    def __init__(self, name, indicators_param, ref, f):
        self.name = name
        self.indicators_param = indicators_param
        self.ref = ref
        self.f = f

class OpenPositionParam():
    def __init__(self, rules):
        self.rules = rules  # rule: f(data, ref, self.entry_index, current_index) -> boolean

class ClosePositionParam():
    def __init__(self, rules):
        self.rules = rules  # rule : f(data, ref, self.entry_index, current_index) -> boolean


class Strategy():

    def __init__(self, name, open_position_param, close_position_param, position):
        self.name = name
        self.open_position = open_position_param
        self.close_position = close_position_param
        self.position = position
        self.have_position = False
        self.entry_index = None
        
    def check_event(self, data, current_index):       
        if not self.have_position:  # check for open position
            rule_triggered = self.check_rules(data, current_index, self.open_position.rules)
            if rule_triggered:
                self.have_position = True
                self.entry_index = current_index
                return OPEN_POSITION, rule_triggered
            
        else:  # check for close positioin
            rule_triggered = self.check_rules(data, current_index, self.close_position.rules)
            if rule_triggered:
                self.have_position = False
                self.entry_index = None
                return CLOSE_POSITION, rule_triggered
        
        return NO_EVENT, None
    
    def check_rules(self, data, current_index, rules):
        # logical OR on all the rules
        for rule in rules:
            if rule.f(data, rule.ref, self.entry_index, current_index):
                return rule.name
        return False

# %%
class BackTest():
    
    def __init__(self, raw_data, strategies):
        
        # class data
        self.data = raw_data
        self.trade_record = pd.DataFrame()
        self.report = pd.DataFrame()
        self.strategies = strategies
        self.all_ti_param = list()
        
        # service
        self.cleaner = DataCleaner()
        self.ti_engine = TechIndicatorEngine()
        
    def initialize(self):
        self.initialize_trade_record()
        self.initialize_report()
        self.initialize_all_ti_param()
        print('[BACKTEST] Initializated')
    
    def initialize_trade_record(self):
        self.trade_record = pd.DataFrame()
        self.trade_record['date_time'] = None
        self.trade_record['strategy_name'] = None
        self.trade_record['position'] = None
        self.trade_record['event'] = None
        self.trade_record['rule'] = None
        self.trade_record['price'] = None
        self.trade_record['trade_return'] = None
        
    def initialize_report(self):
        self.report = pd.DataFrame()
        self.report['strategy_name'] = None
        self.report['occurrence'] = None
        self.report['occ_profit'] = None
        self.report['occ_loss'] = None
        self.report['return_average'] = None
        self.report['return_std'] = None
        
    def initialize_all_ti_param(self):
        for strategy in self.strategies:
            for rule in (strategy.open_position.rules + strategy.close_position.rules):
                for param in rule.indicators_param:
                    
                    if param.name not in self.data.columns:
                        if not self.object_list_contains_object(self.all_ti_param, param):
                            
                            name = self.make_name([i.name for i in self.all_ti_param], param.name)
                            rule.ref[param.name] = name
                            param.name = name
                            self.all_ti_param.append(param)
                        
    @staticmethod
    def object_list_contains_object(obj_list, obj):
        for obj_temp in obj_list:
            if obj_temp == obj:
                return True
        return False
    
    @staticmethod
    def make_name(name_list, target):
        if target not in name_list:
            return target
        i = 2
        while(True):
            new_name = target + '_{}'.format(i)
            if new_name not in name_list:
                return new_name
            i += 1
    
    def data_preprocess(self):
        self.data = self.cleaner.clean(self.data)
        print('[BACKTEST] Finished data pre-process')
        
    def compute_technical_indicator(self):
        for param in self.all_ti_param:
            self.data = self.ti_engine.compute(self.data, param)
        print('[BACKTEST] Finished computation on technical indicators')
        
    def back_test(self):
        for i in self.data.index:
            for strategy in self.strategies:
                event, rule = strategy.check_event(self.data, i)
                if event is not NO_EVENT:
                    date_time = self.data.at[i, DATE_TIME]
                    price = self.data.at[i, CLOSE]
                    self.record_event(date_time, strategy, event, rule, price)
        self.calculate_return()
        print('[BACKTEST] Finished all backtest')
    
    def record_event(self, date_time, strategy, event, rule, price):
        new_row = {'date_time': date_time,
                   'strategy_name': strategy.name,
                   'position': strategy.position,
                   'event': event,
                   'rule': rule,
                   'price': price}
        self.trade_record = self.trade_record.append(new_row, ignore_index=True)
        
    def calculate_return(self):
        self.trade_record.loc[self.trade_record['event'] == OPEN_POSITION, 'trade_return'] = np.NaN
        
        for strategy in self.strategies:
            
            strategy_trade_record = self.trade_record[self.trade_record['strategy_name'] == strategy.name]
            strategy_trade_record['original_id'] = strategy_trade_record.index
            strategy_trade_record = strategy_trade_record.reset_index()
            
            for i in strategy_trade_record.index:
                
                if strategy_trade_record.at[i, 'event'] == CLOSE_POSITION:
                    date_time = strategy_trade_record.at[i, DATE_TIME]
                    entry_price = strategy_trade_record.at[i-1, 'price']
                    exit_price = strategy_trade_record.at[i, 'price']
                    trade_return = self.compute_return(entry_price, exit_price, strategy.position)
                    original_id = strategy_trade_record.at[i, 'original_id']
                    self.trade_record.at[original_id, 'trade_return'] = trade_return
                    
    @staticmethod
    def compute_return(entry_price, exit_price, position):
        if position == BULLISH:
            return (exit_price - entry_price) / entry_price
        elif position == BEARISH:
            return -1 * (exit_price - entry_price) / entry_price
        else:
            raise ValueError('[ERROR] Unknown Position')
    
    def gen_report(self):
        for strategy in self.strategies:
            df = self.trade_record[self.trade_record['strategy_name'] == strategy.name]
            
            occurrence = df[df['event'] == CLOSE_POSITION].shape[0]
            occ_profit = df[df['trade_return'] > 0].shape[0]
            occ_loss = df[df['trade_return'] < 0].shape[0]
            return_average = df['trade_return'].mean()
            return_std = df['trade_return'].std()
            
            new_row = {'strategy_name': strategy.name,
                       'occurrence': occurrence,
                       'occ_profit': occ_profit,
                       'occ_loss': occ_loss,
#                        'return_average': '{:.4%}'.format(return_average),
                       'return_average': return_average,
                       'return_std': return_std}
            self.report = self.report.append(new_row, ignore_index=True)
            
        self.gen_report_summary_row()
        print('[BACKTEST] Generated back test report')
        
    def gen_report_summary_row(self):
        new_row = {'strategy_name': 'summary',
                   'occurrence': self.report['occurrence'].sum(),
                   'occ_profit': self.report['occ_profit'].sum(),
                   'occ_loss': self.report['occ_loss'].sum(),
                   'return_average': '{:.4%}'.format(self.trade_record['trade_return'].mean()),
                   'return_std': self.trade_record['trade_return'].std()}
        self.report = self.report.append(new_row, ignore_index=True)
    
    def run(self):
        self.initialize()
        self.data_preprocess()
        self.compute_technical_indicator()
        self.back_test()
        self.gen_report()
        return

# %%
rule = Rule(
    name = 'basic', 
    indicators_param = [CCIParam(30, 0.015)],
    ref = {TI_CCI: TI_CCI},
    f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < -170)

open_position_param = OpenPositionParam(rules=[rule])

rule = Rule(
    name = 'basic', 
    indicators_param = [CCIParam(30, 0.015)],
    ref = {TI_CCI: TI_CCI},
    f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > 100)

rule_stop_loss = Rule(
    name = 'stop_loss', 
    indicators_param = [IndicatorParam(CLOSE)], 
    ref = {CLOSE: CLOSE}, 
    f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) < -300)

rule_stop_gain = Rule(
    name = 'stop_gain', 
    indicators_param = [IndicatorParam(CLOSE)], 
    ref = {CLOSE: CLOSE}, 
    f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) > 600)

close_position_param = ClosePositionParam(rules=[rule, rule_stop_loss])

CCI_bull_strategy = Strategy('CCI_bull_strategy', open_position_param, close_position_param, BULLISH)


rule = Rule(
    name = 'basic', 
    indicators_param = [CCIParam(30, 0.015)],
    ref = {TI_CCI: TI_CCI},
    f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > 100)

open_position_param = OpenPositionParam(rules=[rule])

rule = Rule(
    name = 'basic', 
    indicators_param = [CCIParam(30, 0.015)],
    ref = {TI_CCI: TI_CCI},
    f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < -170)

rule_stop_loss = Rule(
    name = 'stop_loss', 
    indicators_param = [IndicatorParam(CLOSE)], 
    ref = {CLOSE: CLOSE}, 
    f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) > 300)

rule_stop_gain = Rule(
    name = 'stop_gain', 
    indicators_param = [IndicatorParam(CLOSE)], 
    ref = {CLOSE: CLOSE}, 
    f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) < -600)

close_position_param = ClosePositionParam(rules=[rule, rule_stop_loss])

CCI_bear_strategy = Strategy('CCI_bear_strategy', open_position_param, close_position_param, BEARISH)



df = df = pd.read_csv('data/hsi_hourly.csv')
strategies = [CCI_bull_strategy, CCI_bear_strategy]
backtest = BackTest(df, strategies)
backtest.run()
# Out:
# [BACKTEST] Initializated
# [CLEAN] 7 data items are filled
# [BACKTEST] Finished data pre-process
# [TechIndicatorEngine] Finished computation of CCI
# [BACKTEST] Finished computation on technical indicators
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:107: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
backtest.report
# Out:
#        strategy_name occurrence occ_profit occ_loss return_average  return_std
# 0  CCI_bull_strategy         99         41       58        0.0536%    0.023348
# 1  CCI_bear_strategy        195         59      136       -0.0905%    0.025753
# 2            summary        294        100      194       -0.0420%    0.024939

# %%
class CCIBullishStrategyCreator():
    
    def __init__(self, period=20, ground=-100, sky=100, stop_gain=None, stop_loss=None):
        self.period = period
        self.ground = ground
        self.sky = sky
        self.stop_gain = stop_gain
        self.stop_loss = stop_loss
    
    def create(self):
       
        rule = Rule(
            name = 'basic', 
            indicators_param = [CCIParam(self.period, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < self.ground)

        open_position_param = OpenPositionParam(rules=[rule])

        rule = Rule(
            name = 'basic', 
            indicators_param = [CCIParam(self.period, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > self.sky)

        rules = [rule]

        if self.stop_gain is not None:
            rule_stop_gain = Rule(
                name = 'stop_gain', 
                indicators_param = [IndicatorParam(CLOSE)], 
                ref = {CLOSE: CLOSE}, 
                f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] > self.stop_gain)
            rules.append(rule_stop_gain)

        if self.stop_loss is not None:
            rule_stop_loss = Rule(
                name = 'stop_loss', 
                indicators_param = [IndicatorParam(CLOSE)], 
                ref = {CLOSE: CLOSE}, 
                f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] < self.stop_loss)
            rules.append(rule_stop_loss)

        close_position_param = ClosePositionParam(rules=rules)

        return Strategy('CCI_bull_strategy', open_position_param, close_position_param, BULLISH)

# %%
class CCIBearishStrategyCreator():
    
    def __init__(self, period=20, ground=-100, sky=100, stop_gain=None, stop_loss=None):
        self.period = period
        self.ground = ground
        self.sky = sky
        self.stop_gain = stop_gain
        self.stop_loss = stop_loss
    
    def create(self):
       
        rule = Rule(
            name = 'basic', 
            indicators_param = [CCIParam(self.period, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] > self.sky)

        open_position_param = OpenPositionParam(rules=[rule])

        rule = Rule(
            name = 'basic', 
            indicators_param = [CCIParam(self.period, 0.015)],
            ref = {TI_CCI: TI_CCI},
            f = lambda data, ref, entry_i, i: data.at[i, ref[TI_CCI]] < self.ground)

        rules = [rule]

        if self.stop_gain is not None:
            rule_stop_gain = Rule(
                name = 'stop_gain', 
                indicators_param = [IndicatorParam(CLOSE)], 
                ref = {CLOSE: CLOSE}, 
                f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] < self.stop_gain)
            rules.append(rule_stop_gain)

        if self.stop_loss is not None:
            rule_stop_loss = Rule(
                name = 'stop_loss', 
                indicators_param = [IndicatorParam(CLOSE)], 
                ref = {CLOSE: CLOSE}, 
                f = lambda data, ref, entry_i, i: (data.at[i, CLOSE] - data.at[entry_i, CLOSE]) / data.at[entry_i, CLOSE] > self.stop_loss)
            rules.append(rule_stop_loss)

        close_position_param = ClosePositionParam(rules=rules)

        return Strategy('CCI_bear_strategy', open_position_param, close_position_param, BEARISH)

# %%
cci_bullish_strategy_creator = CCIBullishStrategyCreator(
    period = 20,
    ground = -150, 
    sky = 150, 
    stop_gain = 0.05, 
    stop_loss = -0.05)
CCI_bull_strategy = cci_bullish_strategy_creator.create()

cci_bearish_strategy_creator = CCIBearishStrategyCreator(
    period = 20,
    ground = 150, 
    sky = -150, 
    stop_gain = -0.03, 
    stop_loss = 0.05)
CCI_bear_strategy = cci_bearish_strategy_creator.create()

df = pd.read_csv('data/hsi_hourly.csv')
strategies = [CCI_bull_strategy, CCI_bear_strategy]
backtest = BackTest(df, strategies)
# backtest.run()

backtest.initialize()
backtest.data_preprocess()
backtest.compute_technical_indicator()

backtest.data

# backtest.report
# Out:
# [BACKTEST] Initializated
# [CLEAN] 7 data items are filled
# [BACKTEST] Finished data pre-process
# [TechIndicatorEngine] Finished computation of CCI
# [BACKTEST] Finished computation on technical indicators
#               date_time      open      high       low     close        CCI
# 0      2012-01-30 09:15  20518.00  20518.00  20363.47  20414.82        NaN
# 1      2012-01-30 10:15  20407.75  20407.75  20336.88  20394.78        NaN
# 2      2012-01-30 11:15  20385.29  20443.24  20374.04  20401.32        NaN
# 3      2012-01-30 13:15  20370.87  20390.54  20318.81  20342.81        NaN
# 4      2012-01-30 14:15  20339.58  20339.58  20220.33  20258.05        NaN
# ...                 ...       ...       ...       ...       ...        ...
# 15022  2020-11-06 11:15  25688.27  25696.39  25619.07  25649.51  60.251818
# 15023  2020-11-06 12:15  25640.23  25653.78  25604.68  25627.03  52.284047
# 15024  2020-11-06 13:15  25627.24  25653.45  25540.98  25637.72  45.158915
# 15025  2020-11-06 14:15  25641.66  25708.36  25620.41  25690.42  50.206255
# 15026  2020-11-06 15:15  25692.86  25721.58  25653.39  25712.97  48.316377
#
# [15027 rows x 6 columns]

# %%
backtest.data.to_csv('data/hsi_hourly_cleaned.csv', index=False)

# %%
backtest.trade_record

# %%
backtest.report

# %%
display_df(backtest.trade_record)

# %%
class FieldToTune():
    def __init__(self, name, low_bound, up_bound):
        self.name = name
        self.low_bound = low_bound
        self.up_bound = up_bound

# %%
class StrategyTuner():
    
    def __init__(self, data, strategy_creator, fields_to_tune):
        self.record = pd.DataFrame()
        self.report = pd.DataFrame()
        self.num_trial = 1000
        self.num_top_result = 100
        
        self.data = data
        self.strategy_creator = strategy_creator
        self.strategy = None
        self.fields_to_tune = fields_to_tune
        self.backtest = None
        
        self.file_path = None
        
        self.initialize()
    
    def initialize(self):
        self.update_strategy()
        self.file_path = 'data/' + self.strategy.name + '_param_tune_result.csv'
        self.initialize_backtest()
        self.initialize_record()
        self.initialize_report()
        
    def initialize_backtest(self):
        self.backtest = BackTest(self.data, [self.strategy])
        self.backtest.initialize()
        self.backtest.data_preprocess()
        self.backtest.compute_technical_indicator()
        
    def initialize_record(self):
        self.record = pd.DataFrame()
        for field in self.fields_to_tune:
            self.record[field.name] = None
            
    def initialize_report(self):
        if os.path.isfile(self.file_path):
            self.report = pd.read_csv(self.file_path)
            print('[StrategyTuner] File found: {}'.format(self.file_path))
        else:
            self.report = pd.DataFrame()
            self.report['strategy_name'] = None
            self.report['occurrence'] = None
            self.report['occ_profit'] = None
            self.report['occ_loss'] = None
            self.report['return_average'] = None
            self.report['return_std'] = None
            self.report['simulation_timestamp'] = None
            for field in self.fields_to_tune:
                self.report[field.name] = None
            print('[StrategyTuner] File not found: {}. Created new file.'.format(self.file_path))
    
    def simulate(self):
        self.update_strategy()
        self.backtest.strategies = [self.strategy]
        self.backtest.initialize()
        self.backtest.back_test()
        self.backtest.gen_report()
    
    def update_strategy(self):
        for field in self.fields_to_tune:
            self.strategy_creator.__dict__[field.name] = random.uniform(field.low_bound, field.up_bound)
        self.strategy = self.strategy_creator.create()
    
    def record_simulation(self):
        new_row = {}
        for col in self.record.columns:
            new_row[col] = self.strategy_creator.__dict__[col]
        self.record = self.record.append(new_row, ignore_index=True)
        self.save_top_result(new_row)
    
    def save_top_result(self, param_config):
        new_row = dict()
        new_row.update(dict(self.backtest.report.iloc[0]))
        new_row.update(param_config)
        new_row['simulation_timestamp'] = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        self.report = self.report.append(new_row, ignore_index=True)
        self.report = self.report.sort_values('return_average', ascending=False)
        self.report = self.report[:self.num_top_result]
        self.report = self.report.reset_index(drop=True)
        self.report.to_csv(self.file_path, index=False)
    
    def run_simulation(self):
        for i in range(self.num_trial):
            self.simulate()
            self.record_simulation()
            print(i)
            print('best return = {:.4%}, this return = {:.4%}'.format(self.report.at[0, 'return_average'], self.backtest.report.at[0, 'return_average']))

# %%
df = pd.read_csv('data/hsi_hourly.csv')
cci_bulld_strategy_creator = CCIBullishStrategyCreator()
fields_to_tune = (
    FieldToTune(name='ground', low_bound=-200, up_bound=-50),
    FieldToTune(name='sky', low_bound=50, up_bound=200),
    FieldToTune(name='stop_gain', low_bound=0.03, up_bound=0.1),
    FieldToTune(name='stop_loss', low_bound=-0.02, up_bound=-0.1)
)

strategy_tuner = StrategyTuner(df, cci_bulld_strategy_creator, fields_to_tune)
strategy_tuner.run_simulation()
# Out:
# [BACKTEST] Initializated
# [CLEAN] 7 data items are filled
# [BACKTEST] Finished data pre-process
# [TechIndicatorEngine] Finished computation of CCI
# [BACKTEST] Finished computation on technical indicators
# [StrategyTuner] File found: data/CCI_bull_strategy_param_tune_result.csv
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 0
# best return = 0.8319%, this return = -0.2890%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 1
# best return = 0.8319%, this return = 0.8143%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 2
# best return = 0.8319%, this return = 0.4429%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 3
# best return = 0.8319%, this return = -0.1751%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 4
# best return = 0.8319%, this return = 0.5266%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 5
# best return = 0.8319%, this return = 0.0143%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 6
# best return = 0.8319%, this return = -0.1564%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 7
# best return = 0.8319%, this return = -0.0464%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 8
# best return = 0.8319%, this return = -0.1909%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 9
# best return = 0.8319%, this return = -0.1402%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 10
# best return = 0.8319%, this return = -0.4294%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 11
# best return = 0.8319%, this return = -0.1223%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 12
# best return = 0.8319%, this return = 0.2236%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 13
# best return = 0.8319%, this return = 0.2806%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 14
# best return = 0.8319%, this return = 0.0172%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 15
# best return = 0.8319%, this return = -0.0671%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 16
# best return = 0.8319%, this return = -0.0635%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 17
# best return = 0.8319%, this return = 0.0960%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 18
# best return = 0.8319%, this return = -0.4732%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 19
# best return = 0.8319%, this return = 0.4134%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 20
# best return = 0.8319%, this return = -0.1015%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 21
# best return = 0.8319%, this return = -0.2023%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 22
# best return = 0.8319%, this return = -0.4039%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 23
# best return = 0.8319%, this return = -0.1358%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 24
# best return = 0.8319%, this return = -0.0217%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 25
# best return = 0.8319%, this return = -0.1203%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 26
# best return = 0.8319%, this return = 0.3944%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 27
# best return = 0.8319%, this return = -0.1510%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 28
# best return = 0.8319%, this return = 0.3634%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 29
# best return = 0.8319%, this return = -0.1192%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 30
# best return = 0.8319%, this return = -0.1664%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 31
# best return = 0.8319%, this return = 0.0383%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 32
# best return = 0.8319%, this return = 0.1051%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 33
# best return = 0.8319%, this return = -0.1797%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 34
# best return = 0.8319%, this return = 0.0773%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 35
# best return = 0.8319%, this return = 0.1980%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 36
# best return = 0.8319%, this return = 0.3740%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 37
# best return = 0.8319%, this return = 0.0246%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 38
# best return = 0.8319%, this return = -0.0196%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 39
# best return = 0.8319%, this return = -0.5140%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 40
# best return = 0.8319%, this return = -0.0569%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 41
# best return = 0.8319%, this return = 0.1553%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 42
# best return = 0.8319%, this return = 0.0528%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 43
# best return = 0.8319%, this return = 0.4219%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 44
# best return = 0.8319%, this return = -0.0127%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 45
# best return = 0.8319%, this return = -0.6208%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 46
# best return = 0.8319%, this return = 0.0679%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 47
# best return = 0.8319%, this return = -0.1425%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 48
# best return = 0.8319%, this return = -0.0387%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 49
# best return = 0.8319%, this return = -0.0763%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 50
# best return = 0.8319%, this return = -0.0015%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 51
# best return = 0.8319%, this return = -0.0608%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 52
# best return = 0.8319%, this return = -0.2508%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 53
# best return = 0.8319%, this return = -0.1056%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 54
# best return = 0.8319%, this return = -0.1176%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 55
# best return = 0.8319%, this return = -0.2164%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 56
# best return = 0.8319%, this return = -0.1533%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 57
# best return = 0.8319%, this return = 0.0146%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 58
# best return = 0.8319%, this return = -0.0494%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 59
# best return = 0.8319%, this return = -0.1134%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 60
# best return = 0.8319%, this return = -0.0316%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 61
# best return = 0.8319%, this return = -0.1702%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 62
# best return = 0.8319%, this return = -0.0618%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 63
# best return = 0.8319%, this return = -0.3553%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 64
# best return = 0.8319%, this return = -0.0288%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 65
# best return = 0.8319%, this return = 0.1329%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 66
# best return = 0.8319%, this return = 0.3108%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 67
# best return = 0.8319%, this return = 0.4024%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 68
# best return = 0.8319%, this return = 0.2350%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 69
# best return = 0.8319%, this return = -0.0300%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 70
# best return = 0.8319%, this return = -0.1158%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 71
# best return = 0.8319%, this return = -0.1897%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 72
# best return = 0.8319%, this return = 0.2085%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 73
# best return = 0.8319%, this return = 0.3840%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 74
# best return = 0.8319%, this return = 0.0260%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 75
# best return = 0.8319%, this return = 0.6997%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 76
# best return = 0.8319%, this return = -0.0957%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 77
# best return = 0.8319%, this return = -0.0330%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 78
# best return = 0.8319%, this return = 0.8068%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 79
# best return = 0.8319%, this return = 0.2486%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 80
# best return = 0.8319%, this return = 0.4129%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 81
# best return = 0.8319%, this return = 0.3835%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 82
# best return = 0.8319%, this return = -0.0356%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 83
# best return = 0.8319%, this return = 0.0418%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 84
# best return = 0.8319%, this return = -0.0593%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 85
# best return = 0.8319%, this return = 0.0875%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 86
# best return = 0.8319%, this return = -0.1153%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 87
# best return = 0.8319%, this return = 0.2629%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 88
# best return = 0.8319%, this return = -0.1349%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 89
# best return = 0.8319%, this return = -0.1534%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 90
# best return = 0.8319%, this return = 0.2979%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 91
# best return = 0.8319%, this return = -0.0497%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 92
# best return = 0.8319%, this return = -0.0546%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 93
# best return = 0.8319%, this return = -0.0107%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 94
# best return = 0.8319%, this return = 0.2746%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 95
# best return = 0.8319%, this return = -0.4145%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 96
# best return = 0.8319%, this return = 0.3955%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 97
# best return = 0.8319%, this return = -0.0737%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 98
# best return = 0.8319%, this return = -0.0384%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 99
# best return = 0.8319%, this return = 0.2379%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 100
# best return = 0.8319%, this return = -0.0936%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 101
# best return = 0.8319%, this return = 0.2145%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 102
# best return = 0.8319%, this return = 0.3684%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 103
# best return = 0.8319%, this return = -0.0801%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 104
# best return = 0.8319%, this return = -0.0939%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 105
# best return = 0.8319%, this return = 0.7505%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 106
# best return = 0.8319%, this return = -0.1209%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 107
# best return = 0.8319%, this return = 0.3388%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 108
# best return = 0.8319%, this return = 0.5085%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 109
# best return = 0.8319%, this return = -0.0062%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 110
# best return = 0.8319%, this return = -0.3652%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 111
# best return = 0.8319%, this return = 0.4010%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 112
# best return = 0.8319%, this return = 0.0785%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 113
# best return = 0.8319%, this return = 0.1768%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 114
# best return = 0.8319%, this return = 0.2220%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 115
# best return = 0.8319%, this return = 0.0617%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 116
# best return = 0.8319%, this return = 0.5168%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 117
# best return = 0.8319%, this return = 0.1249%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 118
# best return = 0.8319%, this return = -0.3612%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 119
# best return = 0.8319%, this return = 0.3779%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 120
# best return = 0.8319%, this return = 0.2074%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 121
# best return = 0.8319%, this return = 0.1262%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 122
# best return = 0.8319%, this return = -0.0738%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 123
# best return = 0.8319%, this return = 0.3691%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 124
# best return = 0.8319%, this return = -0.0498%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 125
# best return = 0.8319%, this return = 0.0226%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 126
# best return = 0.8319%, this return = -0.2289%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 127
# best return = 0.8319%, this return = 0.0989%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 128
# best return = 0.8319%, this return = 0.3493%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 129
# best return = 0.8319%, this return = -0.1473%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 130
# best return = 0.8319%, this return = -0.0311%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 131
# best return = 0.8319%, this return = 0.0313%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 132
# best return = 0.8319%, this return = -0.6092%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 133
# best return = 0.8319%, this return = -0.3038%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 134
# best return = 0.8319%, this return = 0.1902%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 135
# best return = 0.8319%, this return = -0.2095%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 136
# best return = 0.8319%, this return = 0.2935%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 137
# best return = 0.8319%, this return = -0.1817%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 138
# best return = 0.8319%, this return = 0.2238%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 139
# best return = 0.8319%, this return = 0.0091%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 140
# best return = 0.8319%, this return = -0.1790%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 141
# best return = 0.8319%, this return = 0.3614%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 142
# best return = 0.8319%, this return = 0.2301%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 143
# best return = 0.8319%, this return = -0.4438%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 144
# best return = 0.8319%, this return = 0.0700%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 145
# best return = 0.8319%, this return = -0.3700%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 146
# best return = 0.8319%, this return = 0.3630%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 147
# best return = 0.8319%, this return = 0.3296%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 148
# best return = 0.8319%, this return = -0.0719%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 149
# best return = 0.8319%, this return = -0.3351%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 150
# best return = 0.8319%, this return = 0.3416%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 151
# best return = 0.8319%, this return = 0.2316%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 152
# best return = 0.8319%, this return = 0.3209%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 153
# best return = 0.8319%, this return = -0.0112%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 154
# best return = 0.8319%, this return = -0.0036%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 155
# best return = 0.8319%, this return = -0.0604%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 156
# best return = 0.8319%, this return = -0.1359%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 157
# best return = 0.8319%, this return = -0.0017%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 158
# best return = 0.8319%, this return = 0.1782%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 159
# best return = 0.8319%, this return = 0.0445%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 160
# best return = 0.8319%, this return = -0.1292%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 161
# best return = 0.8319%, this return = -0.0405%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 162
# best return = 0.8319%, this return = -0.3341%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 163
# best return = 0.8319%, this return = 0.2327%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 164
# best return = 0.8319%, this return = -0.0165%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 165
# best return = 0.8319%, this return = 0.2817%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 166
# best return = 0.8319%, this return = 0.5278%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 167
# best return = 0.8319%, this return = -0.1530%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 168
# best return = 0.8319%, this return = -0.0005%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 169
# best return = 0.8319%, this return = 0.3377%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 170
# best return = 0.8319%, this return = -0.4363%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 171
# best return = 0.8319%, this return = -0.1201%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 172
# best return = 0.8319%, this return = 0.1288%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 173
# best return = 0.8319%, this return = 0.2302%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 174
# best return = 0.8319%, this return = -0.0465%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 175
# best return = 0.8319%, this return = 0.0997%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 176
# best return = 0.8319%, this return = -0.1341%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 177
# best return = 0.8319%, this return = -0.0364%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 178
# best return = 0.8319%, this return = 0.1794%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 179
# best return = 0.8319%, this return = -0.3376%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 180
# best return = 0.8319%, this return = 0.3567%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 181
# best return = 0.8319%, this return = 0.2395%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 182
# best return = 0.8319%, this return = 0.2035%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 183
# best return = 0.8319%, this return = 0.3034%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 184
# best return = 0.8319%, this return = 0.0529%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 185
# best return = 0.8319%, this return = -0.4617%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 186
# best return = 0.8319%, this return = 0.3032%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 187
# best return = 0.8319%, this return = -0.1070%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 188
# best return = 0.8319%, this return = -0.1229%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 189
# best return = 0.8319%, this return = 0.3468%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 190
# best return = 0.8319%, this return = 0.0595%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 191
# best return = 0.8319%, this return = -0.1408%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 192
# best return = 0.8319%, this return = 0.0266%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 193
# best return = 0.8319%, this return = 0.1066%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 194
# best return = 0.8319%, this return = -0.2006%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 195
# best return = 0.8319%, this return = 0.0793%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 196
# best return = 0.8319%, this return = 0.2625%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 197
# best return = 0.8319%, this return = -0.1668%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 198
# best return = 0.8319%, this return = 0.2431%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 199
# best return = 0.8319%, this return = 0.2412%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 200
# best return = 0.8319%, this return = 0.2696%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 201
# best return = 0.8319%, this return = 0.4138%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 202
# best return = 0.8319%, this return = 0.0618%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 203
# best return = 0.8319%, this return = -0.1285%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 204
# best return = 0.8319%, this return = 0.2373%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 205
# best return = 0.8319%, this return = 0.1268%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 206
# best return = 0.8319%, this return = -0.0079%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 207
# best return = 0.8319%, this return = -0.1312%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 208
# best return = 0.8319%, this return = 0.4310%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 209
# best return = 0.8319%, this return = 0.1929%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 210
# best return = 0.8319%, this return = -0.1253%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 211
# best return = 0.8319%, this return = 0.4504%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 212
# best return = 0.8319%, this return = -0.4949%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 213
# best return = 0.8319%, this return = 0.4079%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 214
# best return = 0.8319%, this return = -0.1983%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 215
# best return = 0.8319%, this return = 0.4454%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 216
# best return = 0.8319%, this return = -0.1186%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 217
# best return = 0.8319%, this return = 0.3191%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 218
# best return = 0.8319%, this return = -0.4530%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 219
# best return = 0.8319%, this return = -0.0308%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 220
# best return = 0.8319%, this return = -0.0784%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 221
# best return = 0.8319%, this return = -0.2036%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 222
# best return = 0.8319%, this return = 0.5737%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 223
# best return = 0.8319%, this return = -0.1063%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 224
# best return = 0.8319%, this return = -0.2862%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 225
# best return = 0.8319%, this return = -0.0106%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 226
# best return = 0.8319%, this return = -0.2110%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 227
# best return = 0.8319%, this return = 0.0879%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 228
# best return = 0.8319%, this return = -0.0170%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 229
# best return = 0.8319%, this return = 0.0690%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 230
# best return = 0.8319%, this return = -0.1756%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 231
# best return = 0.8319%, this return = -0.5049%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 232
# best return = 0.8319%, this return = 0.2080%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 233
# best return = 0.8319%, this return = -0.3370%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 234
# best return = 0.8319%, this return = -0.1627%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 235
# best return = 0.8319%, this return = 0.2160%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 236
# best return = 0.8319%, this return = 0.2660%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 237
# best return = 0.8319%, this return = -0.0919%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 238
# best return = 0.8319%, this return = 0.0783%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 239
# best return = 0.8319%, this return = -0.0682%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 240
# best return = 0.8319%, this return = 0.1839%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 241
# best return = 0.8319%, this return = -0.0047%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 242
# best return = 0.8319%, this return = -0.0924%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 243
# best return = 0.8319%, this return = -0.3384%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 244
# best return = 0.8319%, this return = 0.3411%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 245
# best return = 0.8319%, this return = 0.2510%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 246
# best return = 0.8319%, this return = -0.2554%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 247
# best return = 0.8319%, this return = 0.0297%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 248
# best return = 0.8319%, this return = 0.3109%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 249
# best return = 0.8319%, this return = -0.1578%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 250
# best return = 0.8319%, this return = -0.0235%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 251
# best return = 0.8319%, this return = 0.1413%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 252
# best return = 0.8319%, this return = 0.4031%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 253
# best return = 0.8319%, this return = -0.1536%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 254
# best return = 0.8319%, this return = -0.0908%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 255
# best return = 0.8319%, this return = -0.2477%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 256
# best return = 0.8319%, this return = 0.5497%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 257
# best return = 0.8319%, this return = -0.0645%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 258
# best return = 0.8319%, this return = 0.0702%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 259
# best return = 0.8319%, this return = 0.0478%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 260
# best return = 0.8319%, this return = -0.1209%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 261
# best return = 0.8319%, this return = -0.0632%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 262
# best return = 0.8319%, this return = 0.0686%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 263
# best return = 0.8319%, this return = 0.3692%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 264
# best return = 0.8319%, this return = 0.0149%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 265
# best return = 0.8319%, this return = -0.0802%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 266
# best return = 0.8319%, this return = -0.2940%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 267
# best return = 0.8319%, this return = 0.0055%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 268
# best return = 0.8319%, this return = 0.2682%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 269
# best return = 0.8319%, this return = 0.2914%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 270
# best return = 0.8319%, this return = -0.0548%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 271
# best return = 0.8319%, this return = 0.5439%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 272
# best return = 0.8319%, this return = -0.0362%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 273
# best return = 0.8319%, this return = -0.0584%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 274
# best return = 0.8319%, this return = 0.0460%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 275
# best return = 0.8319%, this return = 0.1970%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 276
# best return = 0.8319%, this return = -0.1061%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 277
# best return = 0.8319%, this return = -0.0017%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 278
# best return = 0.8319%, this return = -0.1478%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 279
# best return = 0.8319%, this return = 0.2104%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 280
# best return = 0.8319%, this return = 0.1896%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 281
# best return = 0.8319%, this return = -0.0349%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 282
# best return = 0.8319%, this return = -0.3779%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 283
# best return = 0.8319%, this return = -0.3108%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 284
# best return = 0.8319%, this return = -0.1772%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 285
# best return = 0.8319%, this return = -0.0833%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 286
# best return = 0.8319%, this return = 0.0222%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 287
# best return = 0.8319%, this return = 0.1384%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 288
# best return = 0.8319%, this return = -0.0844%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 289
# best return = 0.8319%, this return = -0.3353%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 290
# best return = 0.8319%, this return = 0.0963%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 291
# best return = 0.8319%, this return = 0.1825%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 292
# best return = 0.8319%, this return = -0.2637%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 293
# best return = 0.8319%, this return = 0.3216%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 294
# best return = 0.8319%, this return = -0.0829%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 295
# best return = 0.8319%, this return = 0.0515%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 296
# best return = 0.8319%, this return = 0.0964%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 297
# best return = 0.8319%, this return = -0.2844%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 298
# best return = 0.8319%, this return = -0.2637%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 299
# best return = 0.8319%, this return = 0.0814%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 300
# best return = 0.8319%, this return = 0.1803%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 301
# best return = 0.8319%, this return = -0.2384%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 302
# best return = 0.8319%, this return = -0.3398%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 303
# best return = 0.8319%, this return = 0.4328%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 304
# best return = 0.8319%, this return = -0.3419%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 305
# best return = 0.8319%, this return = -0.0675%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 306
# best return = 0.8319%, this return = -0.0354%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 307
# best return = 0.8319%, this return = 0.0067%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 308
# best return = 0.8319%, this return = 0.0560%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 309
# best return = 0.8319%, this return = 0.2822%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 310
# best return = 0.8319%, this return = -0.1077%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 311
# best return = 0.8319%, this return = 0.1726%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 312
# best return = 0.8319%, this return = -0.0648%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 313
# best return = 0.8319%, this return = 0.0463%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 314
# best return = 0.8319%, this return = -0.3381%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 315
# best return = 0.8319%, this return = 0.3526%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 316
# best return = 0.8319%, this return = 0.1203%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 317
# best return = 0.8319%, this return = 0.2761%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 318
# best return = 0.8319%, this return = -0.0273%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 319
# best return = 0.8319%, this return = 0.2177%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 320
# best return = 0.8319%, this return = 0.1308%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 321
# best return = 0.8319%, this return = -0.0749%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 322
# best return = 0.8319%, this return = -0.1018%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 323
# best return = 0.8319%, this return = 0.3794%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 324
# best return = 0.8319%, this return = 0.1344%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 325
# best return = 0.8319%, this return = 0.1146%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 326
# best return = 0.8319%, this return = 0.1309%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 327
# best return = 0.8319%, this return = 0.1319%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 328
# ...
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 890
# best return = 0.8319%, this return = 0.2277%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 891
# best return = 0.8319%, this return = -0.0207%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 892
# best return = 0.8319%, this return = -0.6601%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 893
# best return = 0.8319%, this return = -0.1007%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 894
# best return = 0.8319%, this return = 0.5168%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 895
# best return = 0.8319%, this return = -0.0496%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 896
# best return = 0.8319%, this return = 0.3350%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 897
# best return = 0.8319%, this return = -0.0727%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 898
# best return = 0.8319%, this return = 0.0813%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 899
# best return = 0.8319%, this return = 0.0951%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 900
# best return = 0.8319%, this return = -0.0110%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 901
# best return = 0.8319%, this return = -0.4347%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 902
# best return = 0.8319%, this return = -0.0767%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 903
# best return = 0.8319%, this return = -0.0824%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 904
# best return = 0.8319%, this return = 0.0740%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 905
# best return = 0.8319%, this return = 0.3028%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 906
# best return = 0.8319%, this return = -0.1434%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 907
# best return = 0.8319%, this return = -0.0471%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 908
# best return = 0.8319%, this return = 0.4490%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 909
# best return = 0.8319%, this return = -0.0411%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 910
# best return = 0.8319%, this return = 0.0163%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 911
# best return = 0.8319%, this return = -0.3266%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 912
# best return = 0.8319%, this return = 0.5205%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 913
# best return = 0.8319%, this return = -0.1160%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 914
# best return = 0.8319%, this return = 0.7071%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 915
# best return = 0.8319%, this return = 0.1575%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 916
# best return = 0.8319%, this return = 0.0196%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 917
# best return = 0.8319%, this return = 0.0345%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 918
# best return = 0.8319%, this return = -0.0988%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 919
# best return = 0.8319%, this return = 0.1885%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 920
# best return = 0.8319%, this return = 0.0361%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 921
# best return = 0.8319%, this return = 0.1947%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 922
# best return = 0.8319%, this return = -0.0744%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 923
# best return = 0.8319%, this return = 0.3162%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 924
# best return = 0.8319%, this return = 0.2437%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 925
# best return = 0.8319%, this return = 0.4264%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 926
# best return = 0.8319%, this return = 0.0122%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 927
# best return = 0.8319%, this return = 0.1442%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 928
# best return = 0.8319%, this return = -0.0473%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 929
# best return = 0.8319%, this return = -0.0056%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 930
# best return = 0.8319%, this return = 0.1566%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 931
# best return = 0.8319%, this return = -0.1647%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 932
# best return = 0.8319%, this return = -0.5285%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 933
# best return = 0.8319%, this return = 0.0841%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 934
# best return = 0.8319%, this return = 0.0495%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 935
# best return = 0.8319%, this return = 0.0625%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 936
# best return = 0.8319%, this return = -0.0240%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 937
# best return = 0.8319%, this return = -0.0103%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 938
# best return = 0.8319%, this return = 0.0369%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 939
# best return = 0.8319%, this return = 0.0281%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 940
# best return = 0.8319%, this return = 0.1351%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 941
# best return = 0.8319%, this return = -0.1029%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 942
# best return = 0.8319%, this return = 0.2597%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 943
# best return = 0.8319%, this return = 0.1859%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 944
# best return = 0.8319%, this return = -0.0777%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 945
# best return = 0.8319%, this return = -0.0232%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 946
# best return = 0.8319%, this return = -0.1003%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 947
# best return = 0.8319%, this return = 0.3651%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 948
# best return = 0.8319%, this return = 0.4283%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 949
# best return = 0.8319%, this return = 0.1438%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 950
# best return = 0.8319%, this return = 0.0747%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 951
# best return = 0.8319%, this return = -0.0971%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 952
# best return = 0.8319%, this return = -0.0875%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 953
# best return = 0.8319%, this return = -0.4977%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 954
# best return = 0.8319%, this return = 0.0603%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 955
# best return = 0.8319%, this return = -0.0605%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 956
# best return = 0.8319%, this return = 0.2095%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 957
# best return = 0.8319%, this return = -0.0481%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 958
# best return = 0.8319%, this return = 0.3975%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 959
# best return = 0.8319%, this return = 0.0555%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 960
# best return = 0.8319%, this return = -0.2559%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 961
# best return = 0.8319%, this return = -0.1162%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 962
# best return = 0.8319%, this return = -0.1296%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 963
# best return = 0.8319%, this return = 0.0315%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 964
# best return = 0.8319%, this return = -0.0992%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 965
# best return = 0.8319%, this return = 0.0126%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 966
# best return = 0.8319%, this return = 0.0415%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 967
# best return = 0.8319%, this return = -0.1478%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 968
# best return = 0.8319%, this return = 0.3983%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 969
# best return = 0.8319%, this return = -0.0569%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 970
# best return = 0.8319%, this return = 0.3150%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 971
# best return = 0.8319%, this return = -0.0141%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 972
# best return = 0.8319%, this return = -0.3038%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 973
# best return = 0.8319%, this return = 0.0584%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 974
# best return = 0.8319%, this return = 0.2252%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 975
# best return = 0.8319%, this return = -0.0486%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 976
# best return = 0.8319%, this return = 0.3716%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 977
# best return = 0.8319%, this return = 0.2879%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 978
# best return = 0.8319%, this return = 0.5987%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 979
# best return = 0.8319%, this return = -0.1385%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 980
# best return = 0.8319%, this return = 0.2256%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 981
# best return = 0.8319%, this return = 0.3611%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 982
# best return = 0.8319%, this return = 0.2208%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 983
# best return = 0.8319%, this return = -0.0399%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 984
# best return = 0.8319%, this return = -0.0748%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 985
# best return = 0.8319%, this return = -0.1852%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 986
# best return = 0.8319%, this return = 0.4522%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 987
# best return = 0.8319%, this return = 0.1679%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 988
# best return = 0.8319%, this return = 0.1865%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 989
# best return = 0.8319%, this return = 0.0186%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 990
# best return = 0.8319%, this return = 0.1055%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 991
# best return = 0.8319%, this return = 0.1999%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 992
# best return = 0.8319%, this return = 0.0387%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 993
# best return = 0.8319%, this return = -0.0833%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 994
# best return = 0.8319%, this return = -0.0506%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 995
# best return = 0.8326%, this return = 0.8326%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 996
# best return = 0.8326%, this return = 0.1848%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 997
# best return = 0.8326%, this return = 0.1074%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 998
# best return = 0.8326%, this return = 0.2917%
# [BACKTEST] Initializated
# [BACKTEST] Finished all backtest
# [BACKTEST] Generated back test report
# 999
# best return = 0.8326%, this return = 0.0636%

# %%
strategy_tuner.report
# Out:
#         strategy_name  occurrence  occ_profit  occ_loss  return_average  \
# 0   CCI_bull_strategy          70          54        16        0.008319
# 1   CCI_bull_strategy          70          45        25        0.007811
# 2   CCI_bull_strategy          65          46        19        0.007808
# 3   CCI_bull_strategy          68          49        19        0.007775
# 4   CCI_bull_strategy          82          61        21        0.007390
# ..                ...         ...         ...       ...             ...
# 95  CCI_bull_strategy         121          76        45        0.002555
# 96  CCI_bull_strategy         138          85        53        0.002551
# 97  CCI_bull_strategy         203         126        77        0.002526
# 98  CCI_bull_strategy          69          46        23        0.002520
# 99  CCI_bull_strategy         153         106        47        0.002470
#
#     return_std      ground         sky  stop_gain  stop_loss  Unnamed: 10  \
# 0     0.044366 -194.510074  195.529816   0.040471  -0.079177          NaN
# 1     0.052087 -174.119728  198.922367   0.098470  -0.060250          NaN
# 2     0.053541 -184.734346  195.002974   0.086097  -0.077474          NaN
# 3     0.048315 -196.158518  171.606433   0.085192  -0.094779          NaN
# 4     0.052138  -96.677099  198.521348   0.081728  -0.091980          NaN
# ..         ...         ...         ...        ...        ...          ...
# 95    0.041444  -84.942749  192.779923   0.049761  -0.049553          NaN
# 96    0.039692  -74.045119  187.299266   0.052853  -0.047357          NaN
# 97    0.033567  -69.430688  154.722002   0.096622  -0.032392          NaN
# 98    0.042141 -198.917220  163.709005   0.071758  -0.060333          NaN
# 99    0.031677  -98.121651  146.525435   0.037094  -0.066656          NaN
#
#    simulation_timestamp
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ..                  ...
# 95                  NaN
# 96                  NaN
# 97  11/08/2020 16:52:50
# 98                  NaN
# 99                  NaN
#
# [100 rows x 12 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
plt.hist(list(df[TI_CCI]), bins=200)
plt.title('CCI Distribution')
plt.xlabel('CCI')
plt.ylabel('Frequency')
plt.xlim(-500, 500)
plt.xticks(np.arange(-500, 501, 100))
plt.grid(True)
plt.show()
